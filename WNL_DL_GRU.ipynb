# %%
import pandas as pd
import numpy as np
from collections.abc import Iterable
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
import time
from keras.utils import plot_model
import matplotlib.pyplot as plt

# define gvars
SEED = 1080
VCHUNK = 64
NUM_CLASSES = 12

BATCH_SIZE = 32
SPLIT = 0.2
EPOCHS = 50
LR = 0.001
METRIC = 'val_accuracy'
MIN_DELTA = 1e-4
PATIENCE = 100
THRESHOLD = 0.5

# Set random seed
tf.random.set_seed(SEED)

# import from csv to dataframe
df = pd.read_csv('wnl/WNL_TLS_Dataset_ECH.csv', sep='\t')
esni = pd.read_csv('wnl/WNL_TLS_Dataset_ESNI.csv', sep='\t')

# set checkpoint path and filename
check_name = "WNL_CLASS_GRU.chkp"
check_path = "checkpoint/" + check_name

# define our callbacks
callbacks = [

    # define checkpoint callback
    tf.keras.callbacks.ModelCheckpoint (
        check_path,
        monitor= 'val_accuracy',
        verbose= 1,
        save_best_only= True,
        save_weights_only= True,
        mode= 'auto',
        save_freq='epoch',
        options=None,
        initial_value_threshold=THRESHOLD,
    ),

    # # define early stopping callback
    # tf.keras.callbacks.EarlyStopping(
    #     monitor=METRIC,
    #     min_delta=MIN_DELTA,
    #     patience=PATIENCE,
    #     verbose=1
    # ),

]
# Out:
# 2023-04-03 20:58:14.225464: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 20:58:14.378523: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-04-03 20:58:15.012956: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-03 20:58:15.013004: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-03 20:58:15.013008: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
'''https://tls13.xargs.org/#client-hello/annotated'''

def flatten(L):
    '''flattens a list of nested list of arbitrary depth into a single concatenated list'''
    for x in L:
        if isinstance(x, Iterable) and not isinstance(x, (str, bytes)):
            yield from flatten(x)
        else:
            yield x

def padding(A, size):
    '''pads a given list to a given length'''
    t = size - len(A)

    return np.pad(A, pad_width=(0, t), mode='constant')

def parse_CHP(p):
    '''
    implements the Shamsimukhametov et al. bytes recomposition algorithm
    builds a fixed length feature vector from clienthello message
    '''
    T = []
    L = []
    V = []

    handshake_len = sum(p[3:5])
    clienthello_len = sum(p[6:9])
    sid_len = p[43]
    i = 44+sid_len

    sid = p[44:i]
    ciphersuite_len = sum(p[i:i+2])
    ciphersuite = p[i+2:i+2+ciphersuite_len]
    i += 4 + ciphersuite_len

    ext_len = sum(p[i:i+2])
    i = i+2
    
    T.append(padding(sid, 32))
    L.append(handshake_len)
    L.append(clienthello_len)
    L.append(sid_len)
    L.append(ciphersuite_len)
    L.append(ext_len)
    V.append(ciphersuite)
    
    end = i + ext_len
    count = 0   

    while (i < len(p)):

        n_ext_id = sum(p[i:i+2])
        i+=2
        
        n_ext_len = sum(p[i:i+2])
        i+=2

        T.append(n_ext_id)
        L.append(n_ext_len)
        V.append(p[i:i+n_ext_len])
        i+=n_ext_len

    T = padding(list(flatten(T)),40)
    L = padding(list(flatten(L)),13)
    V = list(flatten(V))
    VC = V[:VCHUNK]

    return np.concatenate((T,L,VC))

def parse_SHP(p):
    '''
    implements the Shamsimukhametov et al. bytes recomposition algorithm
    builds a fixed length feature vector from serverhello message
    '''
    T = []
    L = []
    V = []

    handshake_len = sum(p[3:5])
    serverhello_len = sum(p[6:9])
    sid_len = p[43]
    i = 44+sid_len

    sid = p[44:i]
    ciphersuite = sum(p[i:i+2])
    i += 3

    ext_len = sum(p[i:i+2])
    i = i+2
    
    T.append(padding(sid, 32))
    T.append(ciphersuite)
    L.append(handshake_len)
    L.append(serverhello_len)
    L.append(sid_len)
    L.append(ext_len)

    end = i + ext_len
    count = 0    
    
    while (i < len(p)):

        n_ext_id = sum(p[i:i+2])
        i+=2
        
        n_ext_len = sum(p[i:i+2])
        i+=2

        T.append(n_ext_id)
        L.append(n_ext_len)
        V.append(p[i:i+n_ext_len])
        i+=n_ext_len

    T = padding(list(flatten(T)),40)
    L = padding(list(flatten(L)),10)
    V = list(flatten(V))
    VC = V[:VCHUNK]

    return np.concatenate((T,L,VC))

def parse_payload(CH,SH):
    '''builds a concatenated fixed length feature vector of recomposed bytes'''
    chp  = np.fromstring(CH, dtype=int, sep=',')
    shp  = np.fromstring(SH, dtype=int, sep=',')
    chv = parse_CHP(chp)
    shv = parse_SHP(shp)
    return np.concatenate((chv,shv))

# %%
# Transform according to recomposition algorithm
df['X'] = df.apply(lambda row : parse_payload(row['ClientHello'], row['ServerHello']), axis=1)

# %%
# Encode classes into integers as terget variable vector y
labels = df.Label.unique()
df['Label'] = df['Label'].astype('category')
df['target'] = df['Label'].cat.codes
y = df['target'].to_numpy()

# %%
# expand array to proper dims
dfx = pd.DataFrame(df['X'].tolist()).add_prefix("x")
X = dfx.to_numpy(dtype=np.int16)
X = X/256

# %%
# split the training data into train and val_test sets using categorical stratification
X_train, X_val_test, y_train , y_val_test = train_test_split(   X,
                                                                y,
                                                                stratify=y,
                                                                shuffle=True,
                                                                test_size=SPLIT,
                                                                random_state=SEED
                                                                )

# split the val_test data into val and test sets using categorical stratification
X_val, X_test, y_val , y_test = train_test_split(       X_val_test,
                                                        y_val_test,
                                                        test_size=0.5,
                                                        random_state=SEED
                                                        )
# get sizes
len_a = len(X_train)
len_b = len(X_train[5])

# reshape to fit the model
X_train = tf.reshape(X_train,(len_a,len_b,1))

# check for data leakage
print('Data Leak Check')
# need method to check for duplicate rows in data
print(len(X_train))
print(len(X_val))
print(len(X_test))
print(len(X_train), len(y_train), len(X_val_test), len(y_val_test), len(X_val), len(X_test), len(y_val), len(y_test)), print(len(X_train[5]))
# Out:
# Data Leak Check
# 2792
# 349
# 349
# 2792 2792 698 698 349 349 349 349
# 231
# 2023-04-03 20:58:16.835680: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:16.852010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:16.852157: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:16.852546: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 20:58:16.852923: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:16.853026: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:16.853103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:17.195652: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:17.195801: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:17.195882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-03 20:58:17.195950: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7195 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# (None, None)

# %%
# compose the model architecture function
def compose_model():
    in_layer = layers.Input(shape=(len_b,1))
    x = layers.Bidirectional(layers.GRU(256, return_sequences=True))(in_layer)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D()(x)
    x = layers.Bidirectional(layers.GRU(128, return_sequences=True))(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D()(x)
    x = layers.Bidirectional(layers.GRU(64, return_sequences=True))(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D()(x)
    
    # generic stacked dense softmax classifier
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dense(len_b, activation='relu')(x)
    x = layers.Dropout(0.25)(x)
    out_layer = layers.Dense(NUM_CLASSES, activation='softmax')(x)
    return Model(inputs=in_layer, outputs=out_layer)

# instantiate the model
model = compose_model()

# load previously trained weights
#status = model.load_weights(check_path).expect_partial()

# inspect model stack
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 231, 1)]          0
#
#  bidirectional (Bidirectiona  (None, 231, 512)         397824
#  l)
#
#  batch_normalization (BatchN  (None, 231, 512)         2048
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 115, 512)         0
#  )
#
#  bidirectional_1 (Bidirectio  (None, 115, 256)         493056
#  nal)
#
#  batch_normalization_1 (Batc  (None, 115, 256)         1024
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 57, 256)          0
#  1D)
#
#  bidirectional_2 (Bidirectio  (None, 57, 128)          123648
#  nal)
#
#  batch_normalization_2 (Batc  (None, 57, 128)          512
#  hNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, 28, 128)          0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 231)               29799
#
#  dropout (Dropout)           (None, 231)               0
#
#  dense_1 (Dense)             (None, 12)                2784
#
# =================================================================
# Total params: 1,050,695
# Trainable params: 1,048,903
# Non-trainable params: 1,792
# _________________________________________________________________
# None

# %%
# compile and fit the model to the data
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
              metrics=['accuracy'])

# save model plot
plot_model(model, to_file='BDGRU.png')

# start timer
start = time.time()

# fit the model
history = model.fit (   X_train, y_train,
                        epochs=EPOCHS,
                        batch_size=BATCH_SIZE,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=callbacks,
                        )
# stop timer
end = time.time()
# Out:
# Epoch 1/50
# 2023-04-03 20:58:23.317437: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8700
# 2023-04-03 20:58:23.458823: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-03 20:58:23.460165: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x55ad63335240 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-03 20:58:23.460178: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6
# 2023-04-03 20:58:23.463115: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-03 20:58:23.541627: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 87/88 [============================>.] - ETA: 0s - loss: 1.9102 - accuracy: 0.3455
# Epoch 1: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 10s 39ms/step - loss: 1.9092 - accuracy: 0.3453 - val_loss: 2.3947 - val_accuracy: 0.0602
# Epoch 2/50
# 87/88 [============================>.] - ETA: 0s - loss: 1.1738 - accuracy: 0.5585
# Epoch 2: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 3s 29ms/step - loss: 1.1724 - accuracy: 0.5591 - val_loss: 2.4232 - val_accuracy: 0.0802
# Epoch 3/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.8366 - accuracy: 0.6832
# Epoch 3: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 3s 29ms/step - loss: 0.8370 - accuracy: 0.6830 - val_loss: 2.6383 - val_accuracy: 0.0774
# Epoch 4/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.6881 - accuracy: 0.7277
# Epoch 4: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 3s 30ms/step - loss: 0.6877 - accuracy: 0.7278 - val_loss: 2.7521 - val_accuracy: 0.3181
# Epoch 5/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.6123 - accuracy: 0.7579
# Epoch 5: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 3s 30ms/step - loss: 0.6127 - accuracy: 0.7575 - val_loss: 3.7421 - val_accuracy: 0.3266
# Epoch 6/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.5874 - accuracy: 0.7683
# Epoch 6: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 3s 30ms/step - loss: 0.5890 - accuracy: 0.7679 - val_loss: 2.9513 - val_accuracy: 0.3266
# Epoch 7/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.5306 - accuracy: 0.7888
# Epoch 7: val_accuracy improved from 0.50000 to 0.66762, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 31ms/step - loss: 0.5319 - accuracy: 0.7887 - val_loss: 0.7817 - val_accuracy: 0.6676
# Epoch 8/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.5131 - accuracy: 0.7838
# Epoch 8: val_accuracy improved from 0.66762 to 0.75358, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 37ms/step - loss: 0.5142 - accuracy: 0.7837 - val_loss: 0.5755 - val_accuracy: 0.7536
# Epoch 9/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.4747 - accuracy: 0.7953
# Epoch 9: val_accuracy improved from 0.75358 to 0.76791, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 30ms/step - loss: 0.4753 - accuracy: 0.7951 - val_loss: 0.4735 - val_accuracy: 0.7679
# Epoch 10/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.4569 - accuracy: 0.8050
# Epoch 10: val_accuracy did not improve from 0.76791
# 88/88 [==============================] - 3s 30ms/step - loss: 0.4597 - accuracy: 0.8037 - val_loss: 0.5955 - val_accuracy: 0.7278
# Epoch 11/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.4466 - accuracy: 0.8168
# Epoch 11: val_accuracy did not improve from 0.76791
# 88/88 [==============================] - 3s 30ms/step - loss: 0.4479 - accuracy: 0.8159 - val_loss: 0.5460 - val_accuracy: 0.7622
# Epoch 12/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.4196 - accuracy: 0.8258
# Epoch 12: val_accuracy did not improve from 0.76791
# 88/88 [==============================] - 3s 30ms/step - loss: 0.4196 - accuracy: 0.8259 - val_loss: 1.6260 - val_accuracy: 0.4728
# Epoch 13/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3811 - accuracy: 0.8438
# Epoch 13: val_accuracy did not improve from 0.76791
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3821 - accuracy: 0.8435 - val_loss: 1.4500 - val_accuracy: 0.5415
# Epoch 14/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3811 - accuracy: 0.8445
# Epoch 14: val_accuracy improved from 0.76791 to 0.82235, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3818 - accuracy: 0.8438 - val_loss: 0.4232 - val_accuracy: 0.8223
# Epoch 15/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3503 - accuracy: 0.8592
# Epoch 15: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3511 - accuracy: 0.8585 - val_loss: 1.0211 - val_accuracy: 0.7163
# Epoch 16/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3312 - accuracy: 0.8642
# Epoch 16: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3311 - accuracy: 0.8646 - val_loss: 0.5980 - val_accuracy: 0.7507
# Epoch 17/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3475 - accuracy: 0.8606
# Epoch 17: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3474 - accuracy: 0.8607 - val_loss: 3.7777 - val_accuracy: 0.4298
# Epoch 18/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3450 - accuracy: 0.8556
# Epoch 18: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3446 - accuracy: 0.8557 - val_loss: 4.3519 - val_accuracy: 0.3610
# Epoch 19/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3654 - accuracy: 0.8502
# Epoch 19: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3651 - accuracy: 0.8506 - val_loss: 1.1490 - val_accuracy: 0.6590
# Epoch 20/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3424 - accuracy: 0.8642
# Epoch 20: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3439 - accuracy: 0.8635 - val_loss: 1.0428 - val_accuracy: 0.6390
# Epoch 21/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3344 - accuracy: 0.8639
# Epoch 21: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3351 - accuracy: 0.8635 - val_loss: 0.9181 - val_accuracy: 0.6619
# Epoch 22/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3120 - accuracy: 0.8732
# Epoch 22: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3120 - accuracy: 0.8732 - val_loss: 0.8425 - val_accuracy: 0.6791
# Epoch 23/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3027 - accuracy: 0.8750
# Epoch 23: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3040 - accuracy: 0.8750 - val_loss: 0.5666 - val_accuracy: 0.7966
# Epoch 24/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.8754
# Epoch 24: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.3140 - accuracy: 0.8757 - val_loss: 1.5265 - val_accuracy: 0.5759
# Epoch 25/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2873 - accuracy: 0.8797
# Epoch 25: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2872 - accuracy: 0.8797 - val_loss: 0.5463 - val_accuracy: 0.7650
# Epoch 26/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2708 - accuracy: 0.8915
# Epoch 26: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2708 - accuracy: 0.8915 - val_loss: 0.8090 - val_accuracy: 0.7278
# Epoch 27/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2899 - accuracy: 0.8829
# Epoch 27: val_accuracy did not improve from 0.82235
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2892 - accuracy: 0.8832 - val_loss: 0.8129 - val_accuracy: 0.7307
# Epoch 28/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2569 - accuracy: 0.8933
# Epoch 28: val_accuracy improved from 0.82235 to 0.83954, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 31ms/step - loss: 0.2571 - accuracy: 0.8936 - val_loss: 0.3234 - val_accuracy: 0.8395
# Epoch 29/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2435 - accuracy: 0.9034
# Epoch 29: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2436 - accuracy: 0.9033 - val_loss: 0.6619 - val_accuracy: 0.7880
# Epoch 30/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2785 - accuracy: 0.8851
# Epoch 30: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2790 - accuracy: 0.8847 - val_loss: 0.6775 - val_accuracy: 0.7908
# Epoch 31/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2277 - accuracy: 0.9030
# Epoch 31: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2277 - accuracy: 0.9029 - val_loss: 0.5254 - val_accuracy: 0.7880
# Epoch 32/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2674 - accuracy: 0.8976
# Epoch 32: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2674 - accuracy: 0.8976 - val_loss: 1.2370 - val_accuracy: 0.6332
# Epoch 33/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2469 - accuracy: 0.8976
# Epoch 33: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2483 - accuracy: 0.8976 - val_loss: 0.4570 - val_accuracy: 0.8195
# Epoch 34/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2308 - accuracy: 0.9059
# Epoch 34: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2334 - accuracy: 0.9051 - val_loss: 0.5632 - val_accuracy: 0.8023
# Epoch 35/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2336 - accuracy: 0.9106
# Epoch 35: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2343 - accuracy: 0.9105 - val_loss: 3.4665 - val_accuracy: 0.3840
# Epoch 36/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2331 - accuracy: 0.9095
# Epoch 36: val_accuracy did not improve from 0.83954
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2340 - accuracy: 0.9090 - val_loss: 0.4190 - val_accuracy: 0.8138
# Epoch 37/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2136 - accuracy: 0.9152
# Epoch 37: val_accuracy improved from 0.83954 to 0.85673, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 31ms/step - loss: 0.2146 - accuracy: 0.9148 - val_loss: 0.3524 - val_accuracy: 0.8567
# Epoch 38/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2660 - accuracy: 0.9012
# Epoch 38: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2655 - accuracy: 0.9015 - val_loss: 2.1981 - val_accuracy: 0.4212
# Epoch 39/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2228 - accuracy: 0.9174
# Epoch 39: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2232 - accuracy: 0.9173 - val_loss: 0.4903 - val_accuracy: 0.8080
# Epoch 40/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1956 - accuracy: 0.9249
# Epoch 40: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1980 - accuracy: 0.9244 - val_loss: 1.6270 - val_accuracy: 0.6103
# Epoch 41/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2229 - accuracy: 0.9149
# Epoch 41: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.2227 - accuracy: 0.9148 - val_loss: 0.5628 - val_accuracy: 0.7994
# Epoch 42/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9335
# Epoch 42: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1751 - accuracy: 0.9334 - val_loss: 0.4683 - val_accuracy: 0.8367
# Epoch 43/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1792 - accuracy: 0.9303
# Epoch 43: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1790 - accuracy: 0.9302 - val_loss: 0.3745 - val_accuracy: 0.8567
# Epoch 44/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1327 - accuracy: 0.9511
# Epoch 44: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1324 - accuracy: 0.9513 - val_loss: 0.4334 - val_accuracy: 0.8567
# Epoch 45/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1295 - accuracy: 0.9483
# Epoch 45: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1298 - accuracy: 0.9481 - val_loss: 0.5292 - val_accuracy: 0.8453
# Epoch 46/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1592 - accuracy: 0.9375
# Epoch 46: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1609 - accuracy: 0.9370 - val_loss: 0.4207 - val_accuracy: 0.8510
# Epoch 47/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1555 - accuracy: 0.9436
# Epoch 47: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1554 - accuracy: 0.9438 - val_loss: 1.9897 - val_accuracy: 0.5014
# Epoch 48/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1469 - accuracy: 0.9461
# Epoch 48: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1471 - accuracy: 0.9459 - val_loss: 0.7817 - val_accuracy: 0.7335
# Epoch 49/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9569
# Epoch 49: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 3s 30ms/step - loss: 0.1204 - accuracy: 0.9567 - val_loss: 0.5380 - val_accuracy: 0.8567
# Epoch 50/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.1454 - accuracy: 0.9415
# Epoch 50: val_accuracy improved from 0.85673 to 0.86533, saving model to checkpoint/WNL_CLASS_GRU.chkp
# 88/88 [==============================] - 3s 31ms/step - loss: 0.1467 - accuracy: 0.9405 - val_loss: 0.4407 - val_accuracy: 0.8653

# %%
# Make predictions on our test data
y_pred = model.predict(X_test)
y_pred = np.rint(y_pred)
y_pred = np.argmax(y_pred, axis=1)
print(y_pred)
# Out:
# 11/11 [==============================] - 1s 10ms/step
# [ 0  9  9  9  9  1  9  9  9  6  4  9  5  9  4 11  7  9  6  6  2  9 10  6
#  10  0  0  9  9  4 11  0  9  9 10 11 11 11  7 11  4  1  7  1 10  4  9  9
#   9  9  9  0  4  0  6  0 11  4  2  9  6 10  7  4  2  0 11  0  6  9 10  6
#   6  9  9  5 10  7  8  4  8  4 10  5  4 10  1  0  7  0  9  9  1  2  9 10
#  10  9  9  4  6  7  5  1 11 11  5  9  0  9  7 10  9  9  4  5  1 10  9  1
#   5  4  7 11 10  4  0  9  1  2  9  4  1  9  1  6  3  4 11  5  2  6  3  9
#   9  1  0  4  9  9  3  4 10  2  0 11 10  1  5  0  7  9  4  5 10  9 10  6
#   9  1  5  7  5  2  7 10  4  9 10  1  9 11 11  7  6  3 10  3 10  2  6 11
#   6  9  1  2  1  9  9  0  9  1  1  9 11  0  7  0  6  9  4 10 10 10  7  0
#   9  4  0 11  5  1  7  7  4  5  9  3 10 11  9  9  6 10  1 10 10 10 11  9
#  11  3  9  7  1  9  3 10  9  6  0  9  4 10 11  6 11  6  8  9  9 11  7  9
#   0 10  0  4  7  9 10  7 11  4  6 11  5  9  4  9  6  9  9 10 11  4  2  4
#   3  9  4  6  4  6  9  6 10  4  5  9  2  9 10  9 10  9  1  9  9  7  9 10
#   7  1 11  7  0  7  1  6  9  9  9  9  6  0  0 11  1  6  7  1  9  3  4  0
#   5  9 10  6  5  6 10  4 10  4  1 10  6]

# %%
# Evaluate the models performance (I hope this isnt garbage)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#   AppleMusic     0.6786    0.9048    0.7755        21
#          Web     0.8214    0.7667    0.7931        30
#    Kinopoisk     1.0000    1.0000    1.0000        12
# LiveFacebook     1.0000    1.0000    1.0000        10
#  LiveYouTube     0.8333    0.7692    0.8000        39
#      Netflix     0.9444    0.9444    0.9444        18
#   PrimeVideo     0.9375    1.0000    0.9677        30
#   SoundCloud     0.8462    1.0000    0.9167        22
#      Spotify     1.0000    0.5000    0.6667         6
#        Vimeo     0.8452    0.7717    0.8068        92
#  YandexMusic     0.8140    0.8537    0.8333        41
#      YouTube     0.9655    1.0000    0.9825        28
#
#     accuracy                         0.8596       349
#    macro avg     0.8905    0.8759    0.8739       349
# weighted avg     0.8633    0.8596    0.8578       349

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Training Time: "+str(end-start))
# Out:
# Accuracy: 0.8595988538681948
# Training Time: 139.49201035499573

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('BD-GRU Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('bdgru_acc.jpg')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('BD-GRU Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('bdgru_loss.jpg')
plt.show()
