# %%
import pandas as pd
import numpy as np
from collections.abc import Iterable
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
import time
from keras.utils import plot_model
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns

# define gvars
SEED = 1080
VCHUNK = 64
NUM_CLASSES = 12

BATCH_SIZE = 32
SPLIT = 0.2
EPOCHS = 50
LR = 0.001
METRIC = 'val_accuracy'
MIN_DELTA = 1e-4
PATIENCE = 100
THRESHOLD = 0.5

# Set random seed
tf.random.set_seed(SEED)

# import from csv to dataframe
df = pd.read_csv('wnl/WNL_TLS_Dataset_ECH.csv', sep='\t')
esni = pd.read_csv('wnl/WNL_TLS_Dataset_ESNI.csv', sep='\t')

# set checkpoint path and filename
check_name = "WNL_CLASS_CNN.chkp"
check_path = "checkpoint/" + check_name

# define our callbacks
callbacks = [

    # define checkpoint callback
    tf.keras.callbacks.ModelCheckpoint (
        check_path,
        monitor= 'val_accuracy',
        verbose= 1,
        save_best_only= True,
        save_weights_only= True,
        mode= 'auto',
        save_freq='epoch',
        options=None,
        initial_value_threshold=THRESHOLD,
    ),

    # # define early stopping callback
    # tf.keras.callbacks.EarlyStopping(
    #     monitor=METRIC,
    #     min_delta=MIN_DELTA,
    #     patience=PATIENCE,
    #     verbose=1
    # ),

]

# %%
'''https://tls13.xargs.org/#client-hello/annotated'''

def flatten(L):
    '''flattens a list of nested list of arbitrary depth into a single concatenated list'''
    for x in L:
        if isinstance(x, Iterable) and not isinstance(x, (str, bytes)):
            yield from flatten(x)
        else:
            yield x

def padding(A, size):
    '''pads a given list to a given length'''
    t = size - len(A)

    return np.pad(A, pad_width=(0, t), mode='constant')

def parse_CHP(p):
    '''
    implements the Shamsimukhametov et al. bytes recomposition algorithm
    builds a fixed length feature vector from clienthello message
    '''
    T = []
    L = []
    V = []

    handshake_len = sum(p[3:5])
    clienthello_len = sum(p[6:9])
    sid_len = p[43]
    i = 44+sid_len

    sid = p[44:i]
    ciphersuite_len = sum(p[i:i+2])
    ciphersuite = p[i+2:i+2+ciphersuite_len]
    i += 4 + ciphersuite_len

    ext_len = sum(p[i:i+2])
    i = i+2
    
    T.append(padding(sid, 32))
    L.append(handshake_len)
    L.append(clienthello_len)
    L.append(sid_len)
    L.append(ciphersuite_len)
    L.append(ext_len)
    V.append(ciphersuite)
    
    end = i + ext_len
    count = 0   

    while (i < len(p)):

        n_ext_id = sum(p[i:i+2])
        i+=2
        
        n_ext_len = sum(p[i:i+2])
        i+=2

        T.append(n_ext_id)
        L.append(n_ext_len)
        V.append(p[i:i+n_ext_len])
        i+=n_ext_len

    T = padding(list(flatten(T)),40)
    L = padding(list(flatten(L)),13)
    V = list(flatten(V))
    VC = V[:VCHUNK]

    return np.concatenate((T,L,VC))

def parse_SHP(p):
    '''
    implements the Shamsimukhametov et al. bytes recomposition algorithm
    builds a fixed length feature vector from serverhello message
    '''
    T = []
    L = []
    V = []

    handshake_len = sum(p[3:5])
    serverhello_len = sum(p[6:9])
    sid_len = p[43]
    i = 44+sid_len

    sid = p[44:i]
    ciphersuite = sum(p[i:i+2])
    i += 3

    ext_len = sum(p[i:i+2])
    i = i+2
    
    T.append(padding(sid, 32))
    T.append(ciphersuite)
    L.append(handshake_len)
    L.append(serverhello_len)
    L.append(sid_len)
    L.append(ext_len)

    end = i + ext_len
    count = 0    
    
    while (i < len(p)):

        n_ext_id = sum(p[i:i+2])
        i+=2
        
        n_ext_len = sum(p[i:i+2])
        i+=2

        T.append(n_ext_id)
        L.append(n_ext_len)
        V.append(p[i:i+n_ext_len])
        i+=n_ext_len

    T = padding(list(flatten(T)),40)
    L = padding(list(flatten(L)),10)
    V = list(flatten(V))
    VC = V[:VCHUNK]

    return np.concatenate((T,L,VC))

def parse_payload(CH,SH):
    '''builds a concatenated fixed length feature vector of recomposed bytes'''
    chp  = np.fromstring(CH, dtype=int, sep=',')
    shp  = np.fromstring(SH, dtype=int, sep=',')
    chv = parse_CHP(chp)
    shv = parse_SHP(shp)
    return np.concatenate((chv,shv))

# %%
# Transform according to recomposition algorithm
df['X'] = df.apply(lambda row : parse_payload(row['ClientHello'], row['ServerHello']), axis=1)

# %%
# Encode classes into integers as terget variable vector y
labels = df.Label.unique()
df['Label'] = df['Label'].astype('category')
df['target'] = df['Label'].cat.codes
y = df['target'].to_numpy()

# %%
# expand array to proper dims
dfx = pd.DataFrame(df['X'].tolist()).add_prefix("x")
X = dfx.to_numpy(dtype=np.int16)
X = X/256

# %%
# split the training data into train and val_test sets using categorical stratification
X_train, X_val_test, y_train , y_val_test = train_test_split(   X,
                                                                y,
                                                                stratify=y,
                                                                shuffle=True,
                                                                test_size=SPLIT,
                                                                random_state=SEED
                                                                )

# split the val_test data into val and test sets using categorical stratification
X_val, X_test, y_val , y_test = train_test_split(       X_val_test,
                                                        y_val_test,
                                                        test_size=0.5,
                                                        random_state=SEED
                                                        )
# get sizes
len_a = len(X_train)
len_b = len(X_train[5])

# reshape to fit the model
X_train = tf.reshape(X_train,(len_a,len_b,1))

# check for data leakage
print('Data Leak Check')
# need method to check for duplicate rows in data
print(len(X_train))
print(len(X_val))
print(len(X_test))
print(len(X_train), len(y_train), len(X_val_test), len(y_val_test), len(X_val), len(X_test), len(y_val), len(y_test)), print(len(X_train[5]))
# Out:
# Data Leak Check
# 2792
# 349
# 349
# 2792 2792 698 698 349 349 349 349
# 231
# 2023-04-04 13:16:23.856966: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.096412: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.096553: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.099416: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 13:16:24.101359: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.101455: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.101532: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.962166: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.962954: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.963037: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-04 13:16:24.963106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7886 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:01:00.0, compute capability: 8.6
# (None, None)

# %%
# compose the model architecture function
def compose_model():
    in_layer = layers.Input(shape=(len_b,1))
    x = layers.Conv1D(256, 3, padding='valid', strides=1, activation="relu", input_shape=(len_b,1))(in_layer)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D()(x)
    x = layers.Conv1D(128, 3, padding='valid', strides=1, activation="relu", input_shape=(len_b,1))(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D()(x)
    x = layers.Conv1D(64, 3, padding='valid', strides=1, activation="relu", input_shape=(len_b,1))(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPool1D()(x)

    # generic stacked dense softmax classifier
    x = layers.GlobalMaxPooling1D()(x)
    x = layers.Dense(len_b, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    out_layer = layers.Dense(NUM_CLASSES, activation='softmax')(x)
    return Model(inputs=in_layer, outputs=out_layer)

# instantiate the model
model = compose_model()

# load previously trained weights
#status = model.load_weights(check_path).expect_partial()

# inspect model stack
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 231, 1)]          0
#
#  conv1d (Conv1D)             (None, 229, 256)          1024
#
#  batch_normalization (BatchN  (None, 229, 256)         1024
#  ormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 114, 256)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 112, 128)          98432
#
#  batch_normalization_1 (Batc  (None, 112, 128)         512
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 56, 128)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 54, 64)            24640
#
#  batch_normalization_2 (Batc  (None, 54, 64)           256
#  hNormalization)
#
#  max_pooling1d_2 (MaxPooling  (None, 27, 64)           0
#  1D)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 231)               15015
#
#  dropout (Dropout)           (None, 231)               0
#
#  dense_1 (Dense)             (None, 12)                2784
#
# =================================================================
# Total params: 143,687
# Trainable params: 142,791
# Non-trainable params: 896
# _________________________________________________________________
# None

# %%
# compile and fit the model to the data
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=LR),
              metrics=['accuracy'])

# save model plot
plot_model(model, to_file='1DCNN.png')

# start timer
start = time.time()
# fit the model
history = model.fit (   X_train, y_train,
                        epochs=EPOCHS,
                        batch_size=BATCH_SIZE,
                        validation_data=(X_val, y_val),
                        verbose=1,
                        callbacks=callbacks,
                        )
# stop timer
end = time.time()
# Out:
# Epoch 1/50
# 2023-04-04 13:16:27.951947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8700
# 2023-04-04 13:16:29.611725: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-04-04 13:16:29.636103: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fa41c018c90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-04 13:16:29.636123: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 3080 Ti, Compute Capability 8.6
# 2023-04-04 13:16:29.667261: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-04 13:16:29.924640: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 [==============================] - ETA: 0s - loss: 1.8185 - accuracy: 0.4112
# Epoch 1: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 7s 8ms/step - loss: 1.8185 - accuracy: 0.4112 - val_loss: 2.4524 - val_accuracy: 0.0917
# Epoch 2/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.9837 - accuracy: 0.6315
# Epoch 2: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 0s 4ms/step - loss: 0.9698 - accuracy: 0.6375 - val_loss: 2.4662 - val_accuracy: 0.0917
# Epoch 3/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.7654 - accuracy: 0.7159
# Epoch 3: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 0s 4ms/step - loss: 0.7586 - accuracy: 0.7192 - val_loss: 2.7394 - val_accuracy: 0.0917
# Epoch 4/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.6422 - accuracy: 0.7411
# Epoch 4: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6498 - accuracy: 0.7371 - val_loss: 3.2622 - val_accuracy: 0.0917
# Epoch 5/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.6338 - accuracy: 0.7536
# Epoch 5: val_accuracy did not improve from 0.50000
# 88/88 [==============================] - 0s 4ms/step - loss: 0.6378 - accuracy: 0.7532 - val_loss: 2.1625 - val_accuracy: 0.1605
# Epoch 6/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.5352 - accuracy: 0.7780
# Epoch 6: val_accuracy improved from 0.50000 to 0.52149, saving model to checkpoint/WNL_CLASS_CNN.chkp
# 88/88 [==============================] - 0s 5ms/step - loss: 0.5385 - accuracy: 0.7754 - val_loss: 1.2041 - val_accuracy: 0.5215
# Epoch 7/50
# 75/88 [========================>.....] - ETA: 0s - loss: 0.4737 - accuracy: 0.8133
# Epoch 7: val_accuracy improved from 0.52149 to 0.73066, saving model to checkpoint/WNL_CLASS_CNN.chkp
# 88/88 [==============================] - 0s 4ms/step - loss: 0.4736 - accuracy: 0.8138 - val_loss: 0.7825 - val_accuracy: 0.7307
# Epoch 8/50
# 75/88 [========================>.....] - ETA: 0s - loss: 0.4385 - accuracy: 0.8267
# Epoch 8: val_accuracy improved from 0.73066 to 0.79656, saving model to checkpoint/WNL_CLASS_CNN.chkp
# 88/88 [==============================] - 0s 4ms/step - loss: 0.4383 - accuracy: 0.8284 - val_loss: 0.4657 - val_accuracy: 0.7966
# Epoch 9/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.3778 - accuracy: 0.8520
# Epoch 9: val_accuracy improved from 0.79656 to 0.85673, saving model to checkpoint/WNL_CLASS_CNN.chkp
# 88/88 [==============================] - 0s 4ms/step - loss: 0.3723 - accuracy: 0.8524 - val_loss: 0.3555 - val_accuracy: 0.8567
# Epoch 10/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.3603 - accuracy: 0.8534
# Epoch 10: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 0s 4ms/step - loss: 0.3618 - accuracy: 0.8499 - val_loss: 0.4369 - val_accuracy: 0.8166
# Epoch 11/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.3102 - accuracy: 0.8709
# Epoch 11: val_accuracy did not improve from 0.85673
# 88/88 [==============================] - 0s 4ms/step - loss: 0.3121 - accuracy: 0.8693 - val_loss: 0.3413 - val_accuracy: 0.8309
# Epoch 12/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.3027 - accuracy: 0.8746
# Epoch 12: val_accuracy improved from 0.85673 to 0.86246, saving model to checkpoint/WNL_CLASS_CNN.chkp
# 88/88 [==============================] - 0s 4ms/step - loss: 0.3004 - accuracy: 0.8750 - val_loss: 0.3089 - val_accuracy: 0.8625
# Epoch 13/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2602 - accuracy: 0.8961
# Epoch 13: val_accuracy did not improve from 0.86246
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2686 - accuracy: 0.8940 - val_loss: 0.3263 - val_accuracy: 0.8596
# Epoch 14/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2685 - accuracy: 0.8916
# Epoch 14: val_accuracy improved from 0.86246 to 0.88539, saving model to checkpoint/WNL_CLASS_CNN.chkp
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2713 - accuracy: 0.8897 - val_loss: 0.2833 - val_accuracy: 0.8854
# Epoch 15/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.2481 - accuracy: 0.8988
# Epoch 15: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2478 - accuracy: 0.8972 - val_loss: 0.2895 - val_accuracy: 0.8825
# Epoch 16/50
# 75/88 [========================>.....] - ETA: 0s - loss: 0.2970 - accuracy: 0.8817
# Epoch 16: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.3113 - accuracy: 0.8779 - val_loss: 0.3625 - val_accuracy: 0.8252
# Epoch 17/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2522 - accuracy: 0.8989
# Epoch 17: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2547 - accuracy: 0.8976 - val_loss: 0.2768 - val_accuracy: 0.8854
# Epoch 18/50
# 79/88 [=========================>....] - ETA: 0s - loss: 0.2664 - accuracy: 0.8928
# Epoch 18: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2639 - accuracy: 0.8933 - val_loss: 0.3239 - val_accuracy: 0.8539
# Epoch 19/50
# 80/88 [==========================>...] - ETA: 0s - loss: 0.2411 - accuracy: 0.9004
# Epoch 19: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2430 - accuracy: 0.9008 - val_loss: 0.2778 - val_accuracy: 0.8682
# Epoch 20/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.2285 - accuracy: 0.9131
# Epoch 20: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2246 - accuracy: 0.9155 - val_loss: 0.2816 - val_accuracy: 0.8711
# Epoch 21/50
# 75/88 [========================>.....] - ETA: 0s - loss: 0.1911 - accuracy: 0.9221
# Epoch 21: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1920 - accuracy: 0.9219 - val_loss: 0.2756 - val_accuracy: 0.8797
# Epoch 22/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2073 - accuracy: 0.9156
# Epoch 22: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2102 - accuracy: 0.9144 - val_loss: 0.3703 - val_accuracy: 0.8739
# Epoch 23/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2123 - accuracy: 0.9103
# Epoch 23: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2165 - accuracy: 0.9105 - val_loss: 0.3353 - val_accuracy: 0.8739
# Epoch 24/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2113 - accuracy: 0.9099
# Epoch 24: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2131 - accuracy: 0.9097 - val_loss: 0.3029 - val_accuracy: 0.8825
# Epoch 25/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.1678 - accuracy: 0.9307
# Epoch 25: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1653 - accuracy: 0.9312 - val_loss: 0.2906 - val_accuracy: 0.8711
# Epoch 26/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.1550 - accuracy: 0.9391
# Epoch 26: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1580 - accuracy: 0.9388 - val_loss: 0.4156 - val_accuracy: 0.8739
# Epoch 27/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.2837 - accuracy: 0.8941
# Epoch 27: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.2772 - accuracy: 0.8979 - val_loss: 0.3759 - val_accuracy: 0.8510
# Epoch 28/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.1893 - accuracy: 0.9268
# Epoch 28: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1879 - accuracy: 0.9262 - val_loss: 0.7318 - val_accuracy: 0.7479
# Epoch 29/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.1561 - accuracy: 0.9419
# Epoch 29: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1572 - accuracy: 0.9402 - val_loss: 0.3709 - val_accuracy: 0.8596
# Epoch 30/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.1728 - accuracy: 0.9342
# Epoch 30: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1731 - accuracy: 0.9345 - val_loss: 0.3267 - val_accuracy: 0.8653
# Epoch 31/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.1429 - accuracy: 0.9403
# Epoch 31: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1408 - accuracy: 0.9402 - val_loss: 0.5064 - val_accuracy: 0.8596
# Epoch 32/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.1359 - accuracy: 0.9525
# Epoch 32: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9484 - val_loss: 0.4584 - val_accuracy: 0.8711
# Epoch 33/50
# 75/88 [========================>.....] - ETA: 0s - loss: 0.1304 - accuracy: 0.9529
# Epoch 33: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1307 - accuracy: 0.9531 - val_loss: 0.4161 - val_accuracy: 0.8481
# Epoch 34/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.1281 - accuracy: 0.9502
# Epoch 34: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1305 - accuracy: 0.9488 - val_loss: 0.4381 - val_accuracy: 0.8711
# Epoch 35/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.1167 - accuracy: 0.9564
# Epoch 35: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9567 - val_loss: 0.4197 - val_accuracy: 0.8854
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9692
# Epoch 36: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0841 - accuracy: 0.9692 - val_loss: 0.4725 - val_accuracy: 0.8682
# Epoch 37/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.0967 - accuracy: 0.9642
# Epoch 37: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0938 - accuracy: 0.9663 - val_loss: 0.3585 - val_accuracy: 0.8682
# Epoch 38/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.0798 - accuracy: 0.9692
# Epoch 38: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0797 - accuracy: 0.9699 - val_loss: 0.5587 - val_accuracy: 0.8510
# Epoch 39/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.1328 - accuracy: 0.9503
# Epoch 39: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1314 - accuracy: 0.9499 - val_loss: 0.4749 - val_accuracy: 0.8567
# Epoch 40/50
# 74/88 [========================>.....] - ETA: 0s - loss: 0.1079 - accuracy: 0.9590
# Epoch 40: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9595 - val_loss: 0.4517 - val_accuracy: 0.8768
# Epoch 41/50
# 79/88 [=========================>....] - ETA: 0s - loss: 0.0941 - accuracy: 0.9648
# Epoch 41: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0913 - accuracy: 0.9653 - val_loss: 0.4982 - val_accuracy: 0.8768
# Epoch 42/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.0879 - accuracy: 0.9675
# Epoch 42: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0887 - accuracy: 0.9663 - val_loss: 0.4989 - val_accuracy: 0.8768
# Epoch 43/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.0655 - accuracy: 0.9774
# Epoch 43: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0694 - accuracy: 0.9764 - val_loss: 0.4555 - val_accuracy: 0.8768
# Epoch 44/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.0662 - accuracy: 0.9778
# Epoch 44: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0664 - accuracy: 0.9771 - val_loss: 0.5608 - val_accuracy: 0.8768
# Epoch 45/50
# 75/88 [========================>.....] - ETA: 0s - loss: 0.0770 - accuracy: 0.9758
# Epoch 45: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9760 - val_loss: 0.5630 - val_accuracy: 0.8739
# Epoch 46/50
# 78/88 [=========================>....] - ETA: 0s - loss: 0.0382 - accuracy: 0.9876
# Epoch 46: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9864 - val_loss: 0.5675 - val_accuracy: 0.8854
# Epoch 47/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.0682 - accuracy: 0.9752
# Epoch 47: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9753 - val_loss: 0.6142 - val_accuracy: 0.8768
# Epoch 48/50
# 77/88 [=========================>....] - ETA: 0s - loss: 0.0478 - accuracy: 0.9842
# Epoch 48: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9846 - val_loss: 0.5263 - val_accuracy: 0.8567
# Epoch 49/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.0961 - accuracy: 0.9659
# Epoch 49: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9660 - val_loss: 0.7942 - val_accuracy: 0.8195
# Epoch 50/50
# 76/88 [========================>.....] - ETA: 0s - loss: 0.0745 - accuracy: 0.9704
# Epoch 50: val_accuracy did not improve from 0.88539
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0746 - accuracy: 0.9703 - val_loss: 0.5500 - val_accuracy: 0.8539

# %%
# Make predictions on our test data
y_pred = model.predict(X_test)
y_pred = np.rint(y_pred)
y_pred = np.argmax(y_pred, axis=1)
print(y_pred)
# Out:
# 11/11 [==============================] - 0s 1ms/step
# [ 0  4  9  9  9  1  9  4 10  6  4  9  5  9  4 11  7  9  6  6  2  8 10  6
#  10  0  0  5  9  4 11  9  9  9 10 11 11 11  7 11  4  8  7  1 10  4  9  9
#   9  9  1  9  9  0  6  0 11  4  2  9  6  0  7  4  2  0 11  9  6  4  9  6
#   6  9  9  5 10  7  8  4  8  4  1  5  9 10  1  0  7  0  9  4  1  2  9 10
#  10  9  9  4  6  7  5  9 11 11  5  9  0  0  7  7  9  9  9  5  1 10  9  1
#   5  4  7 11  1  4  0  9  1  2  9  4  1  4  1  6  3  4 11  5  2  6  3  9
#   9  1  0  4  9  9  3  4 10  2  1 11 10  1  5  0  7  9  4  5 10  9 10  6
#   9  8  5  7  5  2  7 10  4  8  0  1  9 11 11  7  6  3 10  3 10  2  6 11
#   6  9  1  2  1  9  9  9  9  1  1  9 11  0  7  0  6  4  4 10 10 10  7  0
#   9  4  0 11  5  1  7  7  4  5  9  3 10 11  9  4  6  1  1 10 10 10 11  9
#  11  3  9  7  1  4  3 10  9  6  0  9  4 10 11  6  9  6  8  9  9 11  7  9
#   9 10  4  4  9  9 10  7 11  9  6 11  5  9  4  9  6  9  0 10 11  4  2  4
#   3  9  4  6  4  6  9  6 10  4  5  9  2  9  1  9  1  8  1  9  9  7  9 10
#   7 10 11  7  1  8  1  6  9  4  9  9  6  1  0 11  1  6  8  1  9  3  4  1
#   9  9  0  6  5  6  7  9 10  4  1  7  6]

# %%
# Evaluate the models performance (I hope this isnt garbage)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#   AppleMusic     0.7391    0.8095    0.7727        21
#          Web     0.7353    0.8333    0.7812        30
#    Kinopoisk     1.0000    1.0000    1.0000        12
# LiveFacebook     1.0000    1.0000    1.0000        10
#  LiveYouTube     0.8537    0.8974    0.8750        39
#      Netflix     0.9444    0.9444    0.9444        18
#   PrimeVideo     0.9375    1.0000    0.9677        30
#   SoundCloud     0.8462    1.0000    0.9167        22
#      Spotify     0.6000    1.0000    0.7500         6
#        Vimeo     0.8902    0.7935    0.8391        92
#  YandexMusic     0.8788    0.7073    0.7838        41
#      YouTube     1.0000    1.0000    1.0000        28
#
#     accuracy                         0.8711       349
#    macro avg     0.8688    0.9155    0.8859       349
# weighted avg     0.8772    0.8711    0.8705       349

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Training Time: "+str(end-start))
# Out:
# Accuracy: 0.8710601719197708
# Training Time: 23.27537441253662

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('1D-CNN Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('cnn_acc.jpg')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('1D-CNN Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.savefig('cnn_loss.jpg')
plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support
import seaborn as sns


# plot a confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Transform to df for easier plotting
cm_df = pd.DataFrame(cm, index = labels, columns = labels)

plt.figure(figsize=(5.5,4))
sns.heatmap(cm_df, annot=True, cbar=False)
plt.title('SVM Linear Kernel \nAccuracy:{0:.3f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
